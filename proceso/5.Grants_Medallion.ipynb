# %% [markdown]
# ##Grants

# %%
# %sql
GRANT USE CATALOG ON CATALOG catalog_au TO `DEs`;
GRANT USE CATALOG ON CATALOG catalog_au TO `DAs`;
GRANT USE CATALOG ON CATALOG catalog_au TO `BIs`;

# %%
# %sql
GRANT USE SCHEMA ON SCHEMA catalog_au.bronze TO `DEs`;
GRANT CREATE TABLE, SELECT, MODIFY ON SCHEMA catalog_au.bronze TO `DEs`;

# %%
# %sql
GRANT SELECT ON TABLE catalog_au.bronze.clientes TO `rcarrasco01@outlook.com`;

# %%
# %sql
GRANT USE SCHEMA ON SCHEMA catalog_au.silver TO `DEs`;
GRANT CREATE TABLE, SELECT, MODIFY ON SCHEMA catalog_au.silver TO `DEs`;

# %%
# %sql
GRANT USE SCHEMA ON SCHEMA catalog_au.silver TO `DAs`;
GRANT SELECT ON SCHEMA catalog_au.silver TO `DAs`;

# %%
# %sql
GRANT USE SCHEMA ON SCHEMA catalog_au.golden TO `DAs`;
GRANT SELECT ON SCHEMA catalog_au.golden TO `DAs`;

GRANT USE SCHEMA ON SCHEMA catalog_au.golden TO `BIs`;
GRANT SELECT ON SCHEMA catalog_au.golden TO `BIs`;

# %%
# %sql
SHOW GRANTS ON CATALOG catalog_au;

# %%
# %sql
SHOW GRANTS ON SCHEMA catalog_au.golden;
